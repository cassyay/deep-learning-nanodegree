# %% [markdown]
# # Creating a Filter, and Edge Detection

# %% [markdown]
# ### Import resources and display image

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import cv2
import numpy as np

# %matplotlib inline

# Read in the image
image = mpimg.imread('C:\\Users\\User\\Documents\\Nanodegrees\\Deep-Learning-Nanodegree\\deep-learning-nanodegree\\predicting-bike-sharing\\deep-learning-v2-pytorch\\convolutional-neural-networks\\conv-visualization\\data\\curved_lane.jpg')

plt.imshow(image)

# %% [markdown]
# ### Convert the image to grayscale

# %%
# Convert to grayscale for filtering
gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

plt.imshow(gray, cmap='gray')

# %% [markdown]
# ### Create a custom kernel
#
# The Sobel filter is very commonly used in edge detection and in finding patterns in intensity in an image. Applying a Sobel filter to an image is a way of **taking (an approximation) of the derivative of the image** in the x or y direction, separately.

# %%
# Create a custom kernel

# 3x3 array for edge detection
sobel_y = np.array([[ -1, -2, -1], 
                   [ 0, 0, 0], 
                   [ 1, 2, 1]])

## Create and apply a Sobel x operator
sobel_blur = cv2.Sobel(image, cv2.CV_32F, 0, 1, ksize=5)

# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
filtered_image = cv2.filter2D(gray, -1, sobel_y)

plt.imshow(filtered_image, cmap='gray')

# %% [markdown]
# ### Test out other filters
#
# * Create a filter with decimal value weights.
# * Create a 5x5 filter

# %%
# use decimal weights 

# 3x3 array for edge detection
sobel_y = np.array([[ -.5, -1.5, -.5], 
                   [ 0, 0, 0], 
                   [ .5, 1.5, .5]])

## Create and apply a Sobel x operator
sobel_blur = cv2.Sobel(image, cv2.CV_32F, 0, 1, ksize=5)

# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
filtered_image = cv2.filter2D(gray, -1, sobel_y)

plt.imshow(filtered_image, cmap='gray')

# %%
# 5x5 array for edge detection
sobel_y = np.array([[ -1, -2, -2, -2, -1], 
                   [ 0, 0, 0, 0, 0], 
                   [ 1, 2, 2, 2, 1]])

## Create and apply a Sobel x operator
sobel_blur = cv2.Sobel(image, cv2.CV_32F, 0, 1, ksize=5)

# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
filtered_image = cv2.filter2D(gray, -1, sobel_y)

plt.imshow(filtered_image, cmap='gray')

# %%
# 5x5 array for edge detection using decimal weights 
sobel_y = np.array([[ -.5, -1.5, -1.5, -1.5, -.5], 
                   [ 0, 0, 0, 0, 0], 
                   [ .5, 1.5, 1.5, 1.5, .5]])

## Create and apply a Sobel x operator
sobel_blur = cv2.Sobel(image, cv2.CV_32F, 0, 1, ksize=5)

# Filter the image using filter2D, which has inputs: (grayscale image, bit-depth, kernel)  
filtered_image = cv2.filter2D(gray, -1, sobel_y)

plt.imshow(filtered_image, cmap='gray')
